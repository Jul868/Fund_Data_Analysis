# %% [markdown]
# # Taller#2 Analisis de Datos

# %% [markdown]
# ## Base de datos para ejecutar comandos del taller

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r'C:\Users\HP\Desktop\Fund_Data_Analysis\Taller_Analisis_Data\bear.csv')

# %% [markdown]
# Exploremos las tablas disponibles antes de empezar:

# %%
data.head()
# Out:
#    id  Sex  age  movem_60             timestamp  season  reprod move_status  \
# 0   1    1  2.0  0.014142  2006-05-26T03:00:00Z       1     1.0    resident
# 1   1    1  2.0  0.057070  2006-05-26T04:00:00Z       1     1.0    resident
# 2   1    1  2.0  0.056436  2006-05-26T05:00:00Z       1     1.0    resident
# 3   1    1  2.0  0.024515  2006-05-26T06:00:00Z       1     1.0    resident
# 4   1    1  2.0  0.031000  2006-05-26T07:00:00Z       1     1.0    resident
#
#    cor_hour  altitude_dg     t_period     index    tmx      dayle  study  \
# 0         3   -21.597845    nocturnal  0.125723  19.37  14.830628      1
# 1         4   -14.976951  crepuscular  0.125723  19.37  14.830640      1
# 2         5    -6.597630  crepuscular  0.125723  19.37  14.830691      1
# 3         6     3.022102  crepuscular  0.125723  19.37  14.830640      1
# 4         7    13.474819  crepuscular  0.125723  19.37  14.830662      1
#
#    year     ndvi
# 0     2  0.37345
# 1     2  0.37345
# 2     2  0.37345
# 3     2  0.37345
# 4     2  0.37345
